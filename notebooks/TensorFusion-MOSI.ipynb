# %% [markdown]
# # Tensor Fusion Model - CMU-MOSI Dataset

# %% [markdown]
# In this notebook, we implement the Tensor Fusion Model, and test it on CMU-MOSI dataset.

# %% [markdown]
# ## Importing Libraries

# %%
import os
import sys
import torch
from torch import nn

import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.getcwd())
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))

# %% [markdown]
# ## Importing Helper Functions

# %%
from helpers.data.get_data import get_dataloader
from helpers.unimodals.common_models import GRUWithLinear, MLP
from helpers.fusions.common_fusions import Concat, TensorFusion
from helpers.training.all_in_one import all_in_one_train
from helpers.training.supervised_learning import train, test
from helpers.utils.common_utils import get_default_device, save_results

# %% [markdown]
# ## Loading the Dataset

# %%
traindata, validdata, testdata = get_dataloader(
    '/scratch/rrm9598/data/mosi_raw.pkl', robust_test=False)

# %%
device = get_default_device()
print(device)
# Out:
# cuda

# %% [markdown]
# ## Model Architecture

# %%
encoders = [GRUWithLinear(35, 64, 4, dropout=True, has_padding=True).to(device),
            GRUWithLinear(74, 128, 19, dropout=True, has_padding=True).to(device),
            GRUWithLinear(300, 512, 79, dropout=True, has_padding=True).to(device)]

head = MLP(8000, 512, 1).to(device)

fusion = TensorFusion().to(device)

# %% [markdown]
# ## Training

# %%
FILE_NAME = 'mosi_tfus_r0'

# %%
train_losses, valid_losses = train(
    encoders, fusion, head, traindata, validdata, 100, 
    task="regression", optimtype=torch.optim.AdamW,
    early_stop=False, is_packed=True, lr=1e-3, 
    save=f'/scratch/rrm9598/Multimodal-Sentiment-Analysis/models/{FILE_NAME}.pt', 
    weight_decay=0.01, objective=torch.nn.L1Loss()
)
# Out:
# Epoch [1/100]
# Train Loss: 1.2346
# Valid Loss: 1.2169
# Saving Best
#
# Epoch [2/100]
# Train Loss: 1.0650
# Valid Loss: 1.1676
# Saving Best
#
# Epoch [3/100]
# Train Loss: 0.9647
# Valid Loss: 1.1295
# Saving Best
#
# Epoch [4/100]
# Train Loss: 0.8578
# Valid Loss: 1.0687
# Saving Best
#
# Epoch [5/100]
# Train Loss: 0.7804
# Valid Loss: 1.0087
# Saving Best
#
# Epoch [6/100]
# Train Loss: 0.7723
# Valid Loss: 1.0086
# Saving Best
#
# Epoch [7/100]
# Train Loss: 0.7450
# Valid Loss: 1.0799
#
# Epoch [8/100]
# Train Loss: 0.6642
# Valid Loss: 1.0334
#
# Epoch [9/100]
# Train Loss: 0.6225
# Valid Loss: 1.0060
# Saving Best
#
# Epoch [10/100]
# Train Loss: 0.5558
# Valid Loss: 1.0378
#
# Epoch [11/100]
# Train Loss: 0.5647
# Valid Loss: 1.0217
#
# Epoch [12/100]
# Train Loss: 0.5199
# Valid Loss: 0.9472
# Saving Best
#
# Epoch [13/100]
# Train Loss: 0.4551
# Valid Loss: 0.9717
#
# Epoch [14/100]
# Train Loss: 0.4360
# Valid Loss: 0.9999
#
# Epoch [15/100]
# Train Loss: 0.4212
# Valid Loss: 0.9441
# Saving Best
#
# Epoch [16/100]
# Train Loss: 0.4103
# Valid Loss: 0.9937
#
# Epoch [17/100]
# Train Loss: 0.3943
# Valid Loss: 1.0148
#
# Epoch [18/100]
# Train Loss: 0.3624
# Valid Loss: 0.9741
#
# Epoch [19/100]
# Train Loss: 0.3422
# Valid Loss: 0.9639
#
# Epoch [20/100]
# Train Loss: 0.3230
# Valid Loss: 1.0162
#
# Epoch [21/100]
# Train Loss: 0.3494
# Valid Loss: 0.9825
#
# Epoch [22/100]
# Train Loss: 0.2969
# Valid Loss: 1.0743
#
# Epoch [23/100]
# Train Loss: 0.2981
# Valid Loss: 1.0127
#
# Epoch [24/100]
# Train Loss: 0.2875
# Valid Loss: 0.9714
#
# Epoch [25/100]
# Train Loss: 0.3015
# Valid Loss: 0.9350
# Saving Best
#
# Epoch [26/100]
# Train Loss: 0.2702
# Valid Loss: 0.9983
#
# Epoch [27/100]
# Train Loss: 0.2657
# Valid Loss: 0.9718
#
# Epoch [28/100]
# Train Loss: 0.2535
# Valid Loss: 0.9482
#
# Epoch [29/100]
# Train Loss: 0.2485
# Valid Loss: 0.9676
#
# Epoch [30/100]
# Train Loss: 0.2429
# Valid Loss: 0.9799
#
# Epoch [31/100]
# Train Loss: 0.2366
# Valid Loss: 0.9846
#
# Epoch [32/100]
# Train Loss: 0.2350
# Valid Loss: 0.9631
#
# Epoch [33/100]
# Train Loss: 0.2229
# Valid Loss: 0.9731
#
# Epoch [34/100]
# Train Loss: 0.2269
# Valid Loss: 0.9487
#
# Epoch [35/100]
# Train Loss: 0.2063
# Valid Loss: 0.9676
#
# Epoch [36/100]
# Train Loss: 0.2365
# Valid Loss: 0.9658
#
# Epoch [37/100]
# Train Loss: 0.2054
# Valid Loss: 0.9543
#
# Epoch [38/100]
# Train Loss: 0.2092
# Valid Loss: 0.9518
#
# Epoch [39/100]
# Train Loss: 0.2337
# Valid Loss: 0.9537
#
# Epoch [40/100]
# Train Loss: 0.2046
# Valid Loss: 0.9584
#
# Epoch [41/100]
# Train Loss: 0.2088
# Valid Loss: 0.9564
#
# Epoch [42/100]
# Train Loss: 0.2078
# Valid Loss: 0.9953
#
# Epoch [43/100]
# Train Loss: 0.1918
# Valid Loss: 0.9536
#
# Epoch [44/100]
# Train Loss: 0.1923
# Valid Loss: 0.9776
#
# Epoch [45/100]
# Train Loss: 0.1939
# Valid Loss: 0.9603
#
# Epoch [46/100]
# Train Loss: 0.1887
# Valid Loss: 0.9856
#
# Epoch [47/100]
# Train Loss: 0.1792
# Valid Loss: 0.9349
# Saving Best
#
# Epoch [48/100]
# Train Loss: 0.1904
# Valid Loss: 0.9636
#
# Epoch [49/100]
# Train Loss: 0.1711
# Valid Loss: 1.0026
#
# Epoch [50/100]
# Train Loss: 0.1648
# Valid Loss: 0.9656
#
# Epoch [51/100]
# Train Loss: 0.1696
# Valid Loss: 0.9444
#
# Epoch [52/100]
# Train Loss: 0.1746
# Valid Loss: 0.9605
#
# Epoch [53/100]
# Train Loss: 0.1628
# Valid Loss: 0.9577
#
# Epoch [54/100]
# Train Loss: 0.1645
# Valid Loss: 0.9405
#
# Epoch [55/100]
# Train Loss: 0.1538
# Valid Loss: 0.9763
#
# Epoch [56/100]
# Train Loss: 0.1654
# Valid Loss: 0.9375
#
# Epoch [57/100]
# Train Loss: 0.1534
# Valid Loss: 0.9661
#
# Epoch [58/100]
# Train Loss: 0.1428
# Valid Loss: 0.9801
#
# Epoch [59/100]
# Train Loss: 0.1568
# Valid Loss: 0.9422
#
# Epoch [60/100]
# Train Loss: 0.1608
# Valid Loss: 0.9555
#
# Epoch [61/100]
# Train Loss: 0.1478
# Valid Loss: 0.9786
#
# Epoch [62/100]
# Train Loss: 0.1450
# Valid Loss: 0.9577
#
# Epoch [63/100]
# Train Loss: 0.1494
# Valid Loss: 0.9748
#
# Epoch [64/100]
# Train Loss: 0.1548
# Valid Loss: 0.9657
#
# Epoch [65/100]
# Train Loss: 0.1450
# Valid Loss: 0.9552
#
# Epoch [66/100]
# Train Loss: 0.1392
# Valid Loss: 0.9501
#
# Epoch [67/100]
# Train Loss: 0.1461
# Valid Loss: 0.9725
#
# Epoch [68/100]
# Train Loss: 0.1440
# Valid Loss: 0.9561
#
# Epoch [69/100]
# Train Loss: 0.1392
# Valid Loss: 0.9708
#
# Epoch [70/100]
# Train Loss: 0.1411
# Valid Loss: 0.9399
#
# Epoch [71/100]
# Train Loss: 0.1384
# Valid Loss: 0.9618
#
# Epoch [72/100]
# Train Loss: 0.1436
# Valid Loss: 0.9501
#
# Epoch [73/100]
# Train Loss: 0.1393
# Valid Loss: 0.9504
#
# Epoch [74/100]
# Train Loss: 0.1364
# Valid Loss: 0.9625
#
# Epoch [75/100]
# Train Loss: 0.1336
# Valid Loss: 0.9461
#
# Epoch [76/100]
# Train Loss: 0.1380
# Valid Loss: 0.9761
#
# Epoch [77/100]
# Train Loss: 0.1410
# Valid Loss: 0.9642
#
# Epoch [78/100]
# Train Loss: 0.1286
# Valid Loss: 0.9565
#
# Epoch [79/100]
# Train Loss: 0.1333
# Valid Loss: 0.9686
#
# Epoch [80/100]
# Train Loss: 0.1320
# Valid Loss: 0.9573
#
# Epoch [81/100]
# Train Loss: 0.1353
# Valid Loss: 0.9687
#
# Epoch [82/100]
# Train Loss: 0.1320
# Valid Loss: 0.9617
#
# Epoch [83/100]
# Train Loss: 0.1366
# Valid Loss: 0.9469
#
# Epoch [84/100]
# Train Loss: 0.1392
# Valid Loss: 0.9604
#
# Epoch [85/100]
# Train Loss: 0.1336
# Valid Loss: 0.9765
#
# Epoch [86/100]
# Train Loss: 0.1391
# Valid Loss: 0.9438
#
# Epoch [87/100]
# Train Loss: 0.1307
# Valid Loss: 0.9597
#
# Epoch [88/100]
# Train Loss: 0.1260
# Valid Loss: 0.9685
#
# Epoch [89/100]
# Train Loss: 0.1196
# Valid Loss: 0.9823
#
# Epoch [90/100]
# Train Loss: 0.1191
# Valid Loss: 0.9648
#
# Epoch [91/100]
# Train Loss: 0.1242
# Valid Loss: 0.9775
#
# Epoch [92/100]
# Train Loss: 0.1205
# Valid Loss: 0.9346
# Saving Best
#
# Epoch [93/100]
# Train Loss: 0.1287
# Valid Loss: 0.9611
#
# Epoch [94/100]
# Train Loss: 0.1259
# Valid Loss: 0.9502
#
# Epoch [95/100]
# Train Loss: 0.1335
# Valid Loss: 0.9397
#
# Epoch [96/100]
# Train Loss: 0.1192
# Valid Loss: 0.9521
#
# Epoch [97/100]
# Train Loss: 0.1189
# Valid Loss: 0.9466
#
# Epoch [98/100]
# Train Loss: 0.1195
# Valid Loss: 0.9656
#
# Epoch [99/100]
# Train Loss: 0.1161
# Valid Loss: 0.9756
#
# Epoch [100/100]
# Train Loss: 0.1092
# Valid Loss: 0.9552
#
# Training Time: 2m54s
# Training Peak Mem: 1361.96875
# Training Params: 5488295

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.title('Loss vs. No. of epochs')
# Out:
# Text(0.5, 1.0, 'Loss vs. No. of epochs')

# %%
save_results(train_losses, valid_losses, f'/scratch/rrm9598/Multimodal-Sentiment-Analysis/results/{FILE_NAME}.pkl')

# %% [markdown]
# ## Testing

# %%
model = torch.load(f'/scratch/rrm9598/Multimodal-Sentiment-Analysis/models/{FILE_NAME}.pt').to(device)

test(model, test_dataloaders_all=testdata, dataset='mosi',
     is_packed=True, criterion=torch.nn.L1Loss(), task='posneg-classification', no_robust=True)
# Out:
# Recall: 73.0183% | Total Accuracy: 72.7405%
# Inference Time: 524ms
# Inference Params: 5488295
